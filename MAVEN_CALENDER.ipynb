# %%
import pandas as pd

# %%
df=pd.read_csv('corrected_calender2.csv')
df
# Out:
#            date
# 0    01/01/1997
# 1    01/02/1997
# 2    01/03/1997
# 3    01/04/1997
# 4    01/05/1997
# ..          ...
# 725  27/12/1998
# 726  28/12/1998
# 727  29/12/1998
# 728  30/12/1998
# 729  31/12/1998
#
# [730 rows x 1 columns]

# %%
df.dtypes
# Out:
# date    object
# dtype: object

# %%
df['date']=df['date'].astype('datetime64[ns]')

# %%
print(df['date'].head())
# Out:
# 0   1997-01-01
# 1   1997-01-02
# 2   1997-01-03
# 3   1997-01-04
# 4   1997-01-05
# Name: date, dtype: datetime64[ns]
